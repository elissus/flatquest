# %%
import pandas as pd
import os

# %%
current_dir = os.getcwd()

# %%
csv_path = os.path.join(
    "berlin_merged.csv"  # The CSV file you want to open
)

# %%
df_main = pd.read_csv(csv_path)

# %%
df_main.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  serviceCharge       heatingType  newlyConst  \
# 0             0           0         320.00   central_heating           0
# 1             1           1          79.00   central_heating           0
# 2             2           2         150.00     floor_heating           1
# 3             3           3         228.78     floor_heating           0
# 4             4           4         147.08  district_heating           1
#
#    balcony  telekomUploadSpeed  totalRent  yearConstructed    scoutId  ...  \
# 0        1                32.1    1140.00           1980.0  115671495  ...
# 1        0                40.0     955.00           1918.0  113359456  ...
# 2        1                40.0    1300.00           2019.0  113704695  ...
# 3        1                32.1    1428.78           2017.0  107589685  ...
# 4        1                40.0    1559.05           2019.0  114773727  ...
#
#                                           gym_places  gym_density  \
# ...
